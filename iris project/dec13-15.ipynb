# %%
#MACHINE LEARNING
#supervised-----prediction
#unsupervised---pattern finding

import pandas as pd                                             
x = pd.read_csv('iris.csv')
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
x.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
x.info
# Out:
# <bound method DataFrame.info of       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %%
corr = x.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x = x.drop(columns = ['Id'])   # dropping a column
x
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
corr = x.corr()
plt.figure(figsize=(4,4))
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
x['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
x.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#HISTOGRAM
x['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
x['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
x['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
x['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
#Scatterplot

colors = ['red','green','blue']
species = ['Iris-setosa','Iris-versicolor', 'Iris-virginica' ]

# %%
for i in range(3):
    y = x[x['Species'] == species[i]]
    plt.scatter(y['SepalLengthCm'],y['SepalWidthCm'],c = colors[i],label = species[i])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.legend()

# %%
for i in range(3):
    y = x[x['Species'] == species[i]]
    plt.scatter(y['PetalLengthCm'],y['PetalWidthCm'],c = colors[i],label = species[i])
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.legend()

# %%
for i in range(3):
    y = x[x['Species'] == species[i]]
    plt.scatter(y['SepalLengthCm'],y['PetalLengthCm'],c = colors[i],label = species[i])
plt.xlabel('Sepal length')
plt.ylabel('Petal length')
plt.legend()

# %%
for i in range(3):
    y = x[x['Species'] == species[i]]
    plt.scatter(y['PetalWidthCm'],y['SepalWidthCm'],c = colors[i],label = species[i])
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.legend()

# %%
#encoding/preprocessing

from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
x['Species'] = le.fit_transform(x['Species'])
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        0
# 1            4.9           3.0            1.4           0.2        0
# 2            4.7           3.2            1.3           0.2        0
# 3            4.6           3.1            1.5           0.2        0
# 4            5.0           3.6            1.4           0.2        0

# %%
#training the model

from sklearn.model_selection import train_test_split
y = x.drop(columns = ['Species'])
z = x['Species']
y_train,y_test,z_train,z_test = train_test_split(y,z,test_size=0.30)

# %%
#implementing algorithms
#1.logistic regression

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
# to check which algorithm is used

model.fit(y_train,z_train)
# Out:
# C:\Users\AMARNADH\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#to check efficiency/accuracy of our model

print("Accuracy:",model.score(y_test,z_test)* 100)
# Out:
# Accuracy: 100.0

# %%
#2.knn :- k-nearest neighbour

from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()

# %%
model.fit(y_train,z_train)
# Out:
# KNeighborsClassifier()

# %%
print("Accuracy:",model.score(y_test,z_test)* 100)
# Out:
# Accuracy: 97.77777777777777
# C:\Users\AMARNADH\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
#3.dicissiontree

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()

# %%
model.fit(y_train,z_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy:",model.score(y_test,z_test)* 100)
# Out:
# Accuracy: 97.77777777777777

# %%
# save the model
import pickle
filename = 'savedmodel.sav'
pickle.dump(model,open(filename, 'wb'))

# %%
load_model = pickle.load(open(filename, 'rb'))

load_model.predict([[4.8,3.0,1.4,0.3]])
# Out:
# C:\Users\AMARNADH\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
load_model = pickle.load(open(filename, 'rb'))

load_model.predict([[6.9,3.1,5.4,2.1]])
# Out:
# C:\Users\AMARNADH\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([2])
